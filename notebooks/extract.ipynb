# %%
# import asyncio
import logging
import tomllib
from pathlib import Path

# import httpx
import numpy as np
import pandas as pd

# from aiolimiter import AsyncLimiter
# from selectolax.parser import HTMLParser

# %% [markdown]
# ## Initialize

# %% [markdown]
# ### Set Up Logging

# %%
logging.basicConfig(
    format="{levelname:8s} - {module} - {funcName}: {message}", style="{"
)

logger_main = logging.getLogger(__name__)
# logger_main.setLevel(logging.DEBUG)

# %% [markdown]
# ### Load Dataset
# #### Google Drive Path

# %%
with open(Path.cwd().parent / "secrets.toml", "rb") as f:
    secrets = tomllib.load(f)
    secrets["google_drive"]["path"] = Path(secrets["google_drive"]["path"])

# %% [markdown]
# #### Dataset

# %%
music_path = secrets["google_drive"]["path"].joinpath("BELL INVENTORY.xlsx")
music_raw = pd.read_excel(music_path)
music_raw.head()
# Out:
#       SEASON  KEY STOCK # QTY                          SONG TITLE  \
# 0    Worship  NaN   21867   1       5 HYMNS FOR BEGINNING RINGERS
# 1  Spiritual  NaN   23785   8  5 SPIRITUALS FOR BEGINNING RINGERS
# 2    Worship  NaN    1387   5                               5 X 5
# 3  Christmas  NaN    1435   6                 5 X 5 FOR CHRISTMAS
# 4  Christmas  NaN    1535   6              5 X 5 FOR CHRISTMAS II
#
#          ARRANGER OCTAVES LEVEL     TYPE CHIMES  \
# 0       ANNA PAGE     2-3     1    CHOIR    NaN
# 1       ANNA PAGE     2-3     1    CHOIR    NaN
# 2  DOUGLAS WAGNER       3   NaN  QUINTET    NaN
# 3  DOUGLAS WAGNER       3   NaN  QUINTET    NaN
# 4  DOUGLAS WAGNER       3   NaN  QUINTET    NaN
#
#                            INSTRUMENTS, VOICES, ETC…
# 0  5 SONGS: HOW FIRM A FOUNDATION, GOD IS SO GOOD...
# 1  5 SONGS: MARY HAD A BABY, WERE YOU THERE, HE I...
# 2  5 SONGS: BE THOU MY VISION, CAROL OF THE BELLS...
# 3  5 SONGS: SILENT NIGHT, PATAPAN, IN DULCI JUBIL...
# 4  5 SONGS: WHAT CHILD IS THIS, O COME ALL YE FAI...

# %% [markdown]
# ### Clean Dataset
# #### Raw Dataset Info

# %%
music_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SEASON                     2927 non-null   object
#  1   KEY                        1879 non-null   object
#  2   STOCK #                    2899 non-null   object
#  3   QTY                        2929 non-null   object
#  4   SONG TITLE                 2938 non-null   object
#  5   ARRANGER                   2936 non-null   object
#  6   OCTAVES                    2933 non-null   object
#  7   LEVEL                      1952 non-null   object
#  8   TYPE                       2938 non-null   object
#  9   CHIMES                     629 non-null    object
#  10  INSTRUMENTS, VOICES, ETC…  875 non-null    object
# dtypes: object(11)
# memory usage: 252.6+ KB

# %%
# Keep the original dataset (`music_raw`) separate from the transformed dataset
# (`music`).
music = music_raw.copy()

# %% [markdown]
# #### Column Labels

# %%
music.columns = music.columns.str.lower()
music.columns = music.columns.str.replace(",", "")
music.columns = music.columns.str.replace(" ", "_")
music = music.rename(
    columns={"stock_#": "stock_no", "instruments_voices_etc…": "notes"}
)
music.head()
# Out:
#       season  key stock_no qty                          song_title  \
# 0    Worship  NaN    21867   1       5 HYMNS FOR BEGINNING RINGERS
# 1  Spiritual  NaN    23785   8  5 SPIRITUALS FOR BEGINNING RINGERS
# 2    Worship  NaN     1387   5                               5 X 5
# 3  Christmas  NaN     1435   6                 5 X 5 FOR CHRISTMAS
# 4  Christmas  NaN     1535   6              5 X 5 FOR CHRISTMAS II
#
#          arranger octaves level     type chimes  \
# 0       ANNA PAGE     2-3     1    CHOIR    NaN
# 1       ANNA PAGE     2-3     1    CHOIR    NaN
# 2  DOUGLAS WAGNER       3   NaN  QUINTET    NaN
# 3  DOUGLAS WAGNER       3   NaN  QUINTET    NaN
# 4  DOUGLAS WAGNER       3   NaN  QUINTET    NaN
#
#                                                notes
# 0  5 SONGS: HOW FIRM A FOUNDATION, GOD IS SO GOOD...
# 1  5 SONGS: MARY HAD A BABY, WERE YOU THERE, HE I...
# 2  5 SONGS: BE THOU MY VISION, CAROL OF THE BELLS...
# 3  5 SONGS: SILENT NIGHT, PATAPAN, IN DULCI JUBIL...
# 4  5 SONGS: WHAT CHILD IS THIS, O COME ALL YE FAI...

# %% [markdown]
# #### Convert String Columns to `StringDtype`

# %%
music_cols = music.columns.values
str_cols = music_cols[~np.isin(music_cols, ["qty"])]
music[str_cols] = music[str_cols].astype("string")

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      2927 non-null   string
#  1   key         1879 non-null   string
#  2   stock_no    2899 non-null   string
#  3   qty         2929 non-null   object
#  4   song_title  2938 non-null   string
#  5   arranger    2936 non-null   string
#  6   octaves     2933 non-null   string
#  7   level       1952 non-null   string
#  8   type        2938 non-null   string
#  9   chimes      629 non-null    string
#  10  notes       875 non-null    string
# dtypes: object(1), string(10)
# memory usage: 252.6+ KB

# %% [markdown]
# #### Convert Integer Column to `Int8Dtype`

# %%
music["qty"] = pd.to_numeric(music["qty"], errors="coerce")
music["qty"] = music["qty"].astype("Int8")

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      2927 non-null   string
#  1   key         1879 non-null   string
#  2   stock_no    2899 non-null   string
#  3   qty         2928 non-null   Int8
#  4   song_title  2938 non-null   string
#  5   arranger    2936 non-null   string
#  6   octaves     2933 non-null   string
#  7   level       1952 non-null   string
#  8   type        2938 non-null   string
#  9   chimes      629 non-null    string
#  10  notes       875 non-null    string
# dtypes: Int8(1), string(10)
# memory usage: 235.4 KB

# %% [markdown]
# #### `season` Column

# %%
music["season"].unique()
# Out:
# <StringArray>
# [    'Worship',   'Spiritual',   'Christmas',     'Wedding',     'Secular',
#    'Patriotic',        'Lent',      'Easter',      'Advent',          <NA>,
#        'Movie',       'Radio', 'Palm Sunday']
# Length: 13, dtype: string

# %% [markdown]
# #### Convert `key` Column to a `location` Column

# %%
music["key"].value_counts()
# Out:
# key
# Sample              1835
# Secular               35
# Samples                3
# Slav                   2
# Baptism                1
# mellow dissonant       1
# Hymnal                 1
# Treble-only            1
# Name: count, dtype: Int64

# %%
samples_rows = music[music["key"] == "Samples"].index.values

# %%
music.loc[music["key"] == "Samples", "key"] = "Sample"

# %%
music["key"].value_counts()
# Out:
# key
# Sample              1838
# Secular               35
# Slav                   2
# Baptism                1
# mellow dissonant       1
# Hymnal                 1
# Treble-only            1
# Name: count, dtype: Int64

# %%
music.loc[samples_rows]
# Out:
#        season     key stock_no  qty              song_title        arranger  \
# 2646  Worship  Sample    HB348    1             THREE HYMNS  MICHAEL HELMAN
# 2647  Worship  Sample    HB353    1             THREE HYMNS  MICHAEL HELMAN
# 2648   Easter  Sample    HB362    1  THREE HYMNS FOR EASTER  MICHAEL HELMAN
#
#      octaves level   type chimes  \
# 2646     2-3    2+  CHOIR   <NA>
# 2647     3-5    2+  CHOIR   <NA>
# 2648     2-3     3  CHOIR   <NA>
#
#                                                   notes
# 2646  3 SONGS: HYFRYDOL, THE GOOD SHEPHERD, VARIATIO...
# 2647  3 SONGS: HYFRYDOL, THE GOOD SHEPHERD, VARIATIO...
# 2648  3 SONGS: PALM SUNDAY PRELUDE, NOW THE GREEN BL...

# %% [markdown]
# #### Convert `Secular` Values into a `Secular` Boolean Column

# %%
season_secular = music["season"] == "Secular"
key_secular = music["key"] == "Secular"
secular_index = pd.Index(zip(season_secular, key_secular))

# %%
key_secular.unique()
# Out:
# <BooleanArray>
# [<NA>, False, True]
# Length: 3, dtype: boolean

# %%
secular_index.unique()
# Out:
# MultiIndex([(False,   nan),
#             ( True,   nan),
#             (False, False),
#             (False,  True),
#             (  nan, False),
#             ( True, False),
#             (  nan,   nan)],
#            )

# %%
music[music["stock_no"].isnull()]
# Out:
#          season      key stock_no   qty                          song_title  \
# 97      Worship     <NA>     <NA>     8                    ACROSS THE LANDS
# 144      Easter     <NA>     <NA>     8   ALL HAIL THE POWER OF JESUS' NAME
# 224   Christmas     <NA>     <NA>     8                ANGEL'S ANNOUNCEMENT
# 255   Christmas     <NA>     <NA>     8            ANTIOCH-JOY TO THE WORLD
# 298   Christmas     <NA>     <NA>     6                  AWAY IN THE MANGER
# 346       Radio     <NA>     <NA>     1                     BEATLES BEST OF
# 491   Christmas   Sample     <NA>     1                  CAROL OF THE BIRDS
# 592   Christmas   Sample     <NA>     1                     CHRISTMAS PIPES
# 593   Christmas     <NA>     <NA>     1                CHRISTMAS POPS VOL 1
# 594   Christmas     <NA>     <NA>     1                CHRISTMAS POPS VOL 2
# 611     Worship     <NA>     <NA>     1                     COLD OF BETWEEN
# 769     Worship     <NA>     <NA>     8                            DOXOLOGY
# 784      Easter     <NA>     <NA>     8                      EASTER MORNING
# 925     Secular     <NA>     <NA>     7                 FIDDLER ON THE ROOF
# 979     Worship     <NA>     <NA>     1            GETTING MARRIED (MEDLEY)
# 1002    Worship     <NA>     <NA>     8                        GLORIA PATRI
# 1010    Worship     <NA>     <NA>     8                        GLORY OF GOD
# 1055  Christmas     <NA>     <NA>     2     GOOD CHRISTIAN FRIENDS, REJOICE
# 1061  Christmas     <NA>     <NA>     2                 GOOD KING WENCESLAS
# 1123    Worship     <NA>     <NA>  <NA>                    HANDEL'S ALLEGRO
# 1133  Christmas     <NA>     <NA>     2        HARK! THE HERALD ANGELS SING
# 1145    Worship     <NA>     <NA>     7                            HAWAIIAN
# 1162    Worship     <NA>     <NA>     1             HE SHALL FEED HIS FLOCK
# 1209     Easter   Hymnal     <NA>     8               HOSANNA! LOUD HOSANNA
# 1241  Christmas     <NA>     <NA>     8                         HURON CAROL
# 1448    Worship     <NA>     <NA>     8                 JONAH AND THE WHALE
# 1952    Worship     <NA>     <NA>     1                      OUR GOD REIGNS
# 1985    Worship     <NA>     <NA>     1                              PAVANE
# 2050    Worship     <NA>     <NA>     8    PRAISE TO THE LORD, THE ALMIGHTY
# 2060    Worship     <NA>     <NA>     7                  PRAISE WE THE LORD
# 2096  Christmas     <NA>     <NA>     8  PROCESSIONAL & SUITE FOR CHRISTMAS
# 2324    Worship     <NA>     <NA>     6                        SIMPLE GIFTS
# 2457     Easter   Sample     <NA>     1                        TALLIS CANON
# 2464    Worship   Sample     <NA>     1               TEMPUS ADEST FLORIDUM
# 2481  Christmas     <NA>     <NA>     9  THE BALLAD OF SIOBHAN NI LAOGHAIRE
# 2482    Worship     <NA>     <NA>  <NA>    THE BELLS HEARD 'ROUND THE WORLD
# 2744    Secular     <NA>     <NA>  <NA>                          TYPEWRITER
# 2889  Christmas     <NA>     <NA>     7                   WHILE BY MY SHEEP
# 2920  Christmas  Secular     <NA>     8                    WIZARD IN WINTER
#
#                  arranger   octaves level      type chimes  \
# 97            KEITH GETTY         5  <NA>     CHOIR   <NA>
# 144           KEN HOLLAND         4  <NA>     CHOIR   <NA>
# 224         SANDRA EITHUN       3-5  <NA>     CHOIR   <NA>
# 255        DOUGLAS WAGNER         3  <NA>     CHOIR   <NA>
# 298           LANNY ALLEN         3  <NA>     CHOIR   <NA>
# 346        DOUGLAS WAGNER       3-5  <NA>     CHOIR   <NA>
# 491           CARL WILTSE         2  <NA>     CHOIR   <NA>
# 592           CARL WILTSE         6  <NA>     CHOIR      6
# 593        DOUGLAS WAGNER       2-3     E     CHOIR   <NA>
# 594        DOUGLAS WAGNER       2-4     E     CHOIR   <NA>
# 611            RIMA GREER         1  <NA>      TRIO      1
# 769           ROBIN TRIPP       3-5  <NA>     CHOIR      1
# 784            BEN WATSON         3  <NA>     CHOIR   <NA>
# 925            JERRY BOCK       3-4  <NA>     CHOIR   <NA>
# 979           ROBIN TRIPP         2  <NA>     CHOIR   <NA>
# 1002          ROBIN TRIPP       3-5  <NA>     CHOIR   <NA>
# 1010           MARK HAYES       3-5  <NA>     CHOIR   <NA>
# 1055        JAMES KIMBALL   8 BELLS     E   QUARTET   <NA>
# 1061        JAMES KIMBALL   8 BELLS     E   QUARTET   <NA>
# 1123       MICHAEL KELLER         2  <NA>  ENSEMBLE   <NA>
# 1133        JAMES KIMBALL   8 BELLS     E   QUARTET   <NA>
# 1145      RICHARD COULTER       3-5  <NA>     CHOIR   <NA>
# 1162    CYNTHIA DOBRINSKI       3-5  <NA>     CHOIR   <NA>
# 1209                 <NA>         3  <NA>     CHOIR   <NA>
# 1241          CARL WILTSE         3  <NA>     CHOIR   <NA>
# 1448      TAMMY RAWLINSON         2  <NA>     CHOIR   <NA>
# 1952        SANDRA EITHUN  12 BELLS   1-2    SEXTET   <NA>
# 1985         ANGES FRENCH        5+  <NA>     CHOIR   <NA>
# 2050           JOHN PAIGE         5  <NA>     CHOIR   <NA>
# 2060          CARL WILTSE         5  <NA>     CHOIR   <NA>
# 2096          KEN HOLLAND       3-5  <NA>     CHOIR   <NA>
# 2324          CARL WILTSE         4  <NA>     CHOIR   <NA>
# 2457          CARL WILTSE         3  <NA>     CHOIR   <NA>
# 2464          CARL WILTSE         3  <NA>     CHOIR   <NA>
# 2481  CATHERINE MCMICHAEL       3-7    3+     CHOIR      3
# 2482          ROBIN HABER         3     2     CHOIR   <NA>
# 2744        SMITH & PATTY         3     M      SOLO   <NA>
# 2889          CARL WILTSE         4  <NA>     CHOIR   <NA>
# 2920            TIM WAUGH         5  <NA>     CHOIR   <NA>
#
#                                                   notes
# 97                                                 HYMN
# 144                                                <NA>
# 224                                           NARRATION
# 255                                                <NA>
# 298                               ORGAN, FLUTE, TRUMPET
# 346   8 SONGS: MICHELLE, YESTERDAY, I WANT TO HOLD Y...
# 491                                                <NA>
# 592                                                <NA>
# 593   10 SONGS: LITTLE DRUMMER BOY, RUDOLPH, GRANDMA...
# 594   10 SONGS: I HEARD THE BELLS ON CHRISTMAS DAY, ...
# 611                                     BELLS OR CHIMES
# 769                                          CHIME SOLO
# 784                                                <NA>
# 925                                                <NA>
# 979                                                <NA>
# 1002                                               <NA>
# 1010                                            W/CHOIR
# 1055                                               <NA>
# 1061                                               <NA>
# 1123                                               <NA>
# 1133                                               <NA>
# 1145                                               <NA>
# 1162                                               <NA>
# 1209                WITH CHOIR & CONGREGATION ON EASTER
# 1241                                               <NA>
# 1448                               CHILDREN'S NARRATION
# 1952  6 SONGS: MORNING HAS BROKEN, JESUS WALKED THIS...
# 1985                                               <NA>
# 2050                                         WITH CHOIR
# 2060                                               <NA>
# 2096                                               <NA>
# 2324                                               <NA>
# 2457                                               <NA>
# 2464                                               <NA>
# 2481                                               <NA>
# 2482                                               <NA>
# 2744                                              PIANO
# 2889                                               <NA>
# 2920                        C INSTRUMENT, TIMPANI, BASS

# %%
music[music["arranger"].isnull()]
# Out:
#        season     key stock_no  qty             song_title arranger octaves  \
# 415   Wedding    <NA>             8           BRIDAL MARCH     <NA>     3-4
# 1209   Easter  Hymnal     <NA>    8  HOSANNA! LOUD HOSANNA     <NA>       3
#
#      level   type chimes                                notes
# 415   <NA>  CHOIR   <NA>                                 <NA>
# 1209  <NA>  CHOIR   <NA>  WITH CHOIR & CONGREGATION ON EASTER

# %%
music.shape
# Out:
# (2938, 11)

# %% [markdown]
# #### Create Browser Instance

# %% [markdown]
# ## Extract

# %% [markdown]
# ### Main Scraping Function
